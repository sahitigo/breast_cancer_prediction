# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Breast cancer is a common cancer in women, accounting for 25% of cases worldwide. The challenge is classifying tumors as malignant or benign. We'll use machine learning on the Breast Cancer Wisconsin Dataset to build accurate classification models, fine-tune hyperparameters, and compare evaluation metrics.

# %% [markdown]
# ### Importing libraries:

# %%
from genie_eda import apply_eda 
from model_library import classification_models

import statsmodels.api as sm
import pandas as pd
import numpy as np

import warning

# %% [markdown]
# ### Data Loading and Description

# %%
df = pd.read_csv("breast-cancer.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.corr()
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %% [markdown]
# ## Exploratory Data Analysis:

# %% [markdown]
# Exploratory Data Analysis (EDA) is a vital step in understanding the distribution and characteristics of the dataset. It assists in identifying patterns, outliers, and relationships between variables. In this specific dataset, which consists of 569 observations and 32 features, conducting EDA is crucial for determining which features are relevant in predicting whether a tumor is malignant or benign.

# %%
df = apply_eda(df,drop_null='no',fill_null='mean',columns_to_drop=['id'])
# Out:
# DataFrame shape:
# (569, 31)
#
#
# Checking for null values:
# Total Null values count: 0
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# ...

# %% [markdown]
# We are checking for multicollinearity by calculating VIF. Then by sorting them in descending order, removed those features which has VIF<10.Thereby retaining features, which are actually significant

# %% [markdown]
#    - Let's perform further steps of the EDA by importing the apply_eda function

# %%
df.dtypes
# Out:
# texture_se              float64
# area_se                 float64
# smoothness_se           float64
# concavity_se            float64
# symmetry_se             float64
# fractal_dimension_se    float64
# concavity_worst         float64
# diagnosis_B             float64
# diagnosis_M             float64
# dtype: object

# %% [markdown]
# - We are now left with 9 columns after removing multicollinear features.

# %%
df.head()
# Out:
#    texture_se  area_se  smoothness_se  concavity_se  symmetry_se  \
# 0      0.9053   153.40       0.006399       0.05373      0.03003
# 1      0.7339    74.08       0.005225       0.01860      0.01389
# 2      0.7869    94.03       0.006150       0.03832      0.02250
# 3      1.1560    27.23       0.009110       0.05661      0.05963
# 4      0.7813    94.44       0.011490       0.05688      0.01756
#
#    fractal_dimension_se  concavity_worst  diagnosis_B  diagnosis_M
# 0              0.006193           0.7119          0.0          1.0
# 1              0.003532           0.2416          0.0          1.0
# 2              0.004571           0.4504          0.0          1.0
# 3              0.009208           0.6869          0.0          1.0
# 4              0.005115           0.4000          0.0          1.0

# %%
df.corr()
# Out:
#                       texture_se   area_se  smoothness_se  concavity_se  \
# texture_se              1.000000  0.111567       0.397243      0.194998
# area_se                 0.111567  1.000000       0.075150      0.270895
# smoothness_se           0.397243  0.075150       1.000000      0.268685
# concavity_se            0.194998  0.270895       0.268685      1.000000
# symmetry_se             0.411621  0.134109       0.413506      0.309429
# fractal_dimension_se    0.279723  0.127071       0.427374      0.727372
# concavity_worst        -0.068956  0.385100      -0.058298      0.662564
# diagnosis_B             0.008303 -0.548236       0.067016     -0.253730
# diagnosis_M            -0.008303  0.548236      -0.067016      0.253730
#
#                       symmetry_se  fractal_dimension_se  concavity_worst  \
# texture_se               0.411621              0.279723        -0.068956
# area_se                  0.134109              0.127071         0.385100
# ...

# %% [markdown]
# - It can be seen that the features are no more correlated.

# %% [markdown]
# ## Model Prediction:

# %% [markdown]
#  **Label** : Diagnosis.
#
# **Features** : All the columns except the Diagnosis.

# %%
y = df['diagnosis_B']
X = df.drop(columns=['diagnosis_M','diagnosis_B'],axis=1)

classification_models(X, y, max_depth=2, leaf_nodes=3, n_neighbors=5)
# Out:
# Training Logistic Regression...
#
# Training KNN Classification...
#
# Training Decision Tree Classification...
# C:\Users\sahit\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...
